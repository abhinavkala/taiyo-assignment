# %%
import requests
import json
import os
import pandas as pd
import time
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
class Weather_API:
    
    def __init__ (self, keyword):
        self.keyword = keyword
        
    def json_print(self, obj):
        # create a formatted string of the Python JSON object
        with open('api_data.txt', 'w') as json_file:
            json.dump(obj, json_file)
        text = json.dumps(obj, sort_keys=True, indent=4)
        print(text)
        
    def create_dataframe(self, obj):
        
        # creating a dataframe from nested JSON objects
        FIELDS = ["source.id", "source.name", "author", "title", "description", "url", "urlToImage", "publishedAt", "content"]
        df = pd.json_normalize(obj['articles'])
        final_df = df[FIELDS]
        #final_df.set_index('source.id', inplace = True)
        display(final_df.head())

    
    def news_api(self):
        
        # Use the news-api to obtain articles published from
        url = ('https://newsapi.org/v2/everything?'
       'q={keyword}&'
       'apiKey=4e70cabb80884db08524a28ac33cdc1d'.format(keyword = self.keyword))
        
        
        response = requests.get(url)
        if (response.status_code == 200):
            print('API call successful!')
            json_response = response.json()
            if(len(json_response['articles']) == 0):
                print('No News Articles Found')
            else:
                
                # Print a String in Json Format
                self.json_print(json_response)
                
                
                
                # Create a pandas DataFrame
                self.create_dataframe(json_response)
                    
        else:
            print('Status code: ', response.status_code)

# %%
class Web_Scraping:
    
    def __init__(self, location):
        self.location = location
        
    def selenium_webdriver(self):
        
        # Start the Driver
        driver = webdriver.Chrome(executable_path = r"C:\Users\Aditya\Downloads\chromedriver_win32\chromedriver.exe")
        
        # Hit the url of NASA Earth Data website and wait for 15 seconds.
        url = ('https://earthdata.nasa.gov/search?q={location}'.format(location = self.location))
        driver.get(url)
        time.sleep(15)
        
        # Driver scrolls down 25 times to load the table.
        for i in range(0,30):
            driver.execute_script("window.scrollBy(0,6000)")
            time.sleep(10)
            
        # Fetch the webpage and store in a variable.
        webpage = driver.page_source
        
        # Parse the page using BeautifulSoup
        HTMLPage = BeautifulSoup(webpage, 'html.parser')
        
        titles = []
        description = []
        links = []

        for lists in HTMLPage.find_all(class_ = 'result'):
            if (lists.span.text != '' and len(lists.find_all('p')) != 0):
                titles.append(lists.span.text)
                description.append(lists.find('p', class_ = '').text)
                links.append(lists.find('p', class_ = 'search-link').text)
        
        # Create a DataFrame
        df = pd.DataFrame(list(zip(titles, description, links)),
               columns =['title', 'description', 'link'])
        
        display(df)
        
        # Store to csv file
        df.to_csv('ws.csv', sep=',', index=False,header=True)
        
        print('Web Scraping Successful!')

# %%
keyword = input('Enter Keyword to be searched: ').lower()
w_api = Weather_API(keyword)
w_api.news_api()

location = input('Enter Location: ').lower()
ws = Web_Scraping('India')
ws.selenium_webdriver()
# Out:
# Enter Keyword to be searched: mumbai
# API call successful!
# {
#     "articles": [
#         {
#             "author": null,
#             "content": "Mumbai Indians lost their opening game of the season to Royal Challengers Bangalore\r\n<table>\r\n<tr><td>Indian Premier League, Chennai</td></tr><tr><td>Mumbai Indians 152 (20 overs): Suryakumar 56 (36)\u2026 [+1462 chars]",
#             "description": "Defending champions Mumbai Indians somehow earn their first win of the new Indian Premier League season with a 10-run victory against Kolkata Knight Riders.",
#             "publishedAt": "2021-04-13T18:20:45Z",
#             "source": {
#                 "id": "bbc-news",
#                 "name": "BBC News"
#             },
#             "title": "Defending champions Mumbai stifle Kolkata for first IPL win",
#             "url": "https://www.bbc.co.uk/sport/cricket/56712922",
#             "urlToImage": "https://ichef.bbci.co.uk/live-experience/cps/624/cpsprodpb/0816/production/_118007020_mumbaiindianscelebrate.jpg"
#         },
#         {
#             "author": "The New York Times",
#             "content": "LiveUpdated\u00a0March 21, 2021, 11:04 a.m. ET\r\nMarch 21, 2021, 11:04 a.m. ET\r\nNew York finds its first case of a troubling variant first identified in Brazil. India battles a second wave centered around \u2026 [+15583 chars]",
#             "description": "New York finds its first case of a troubling variant first identified in Brazil. India battles a second wave centered around Mumbai, along with vaccine skepticism.",
#             "publishedAt": "2021-03-21T14:57:26Z",
#             "source": {
#                 "id": null,
#                 "name": "New York Times"
#             },
#             "title": "Covid Updates: Spring Breakers Defy Curfew in Miami Beach",
#             "url": "https://www.nytimes.com/live/2021/03/21/world/covid-19-coronavirus",
#             "urlToImage": "https://static01.nyt.com/images/2021/03/21/world/21virus-briefing-miami-beach1/21virus-briefing-miami-beach1-facebookJumbo.jpg"
#         },
#         {
#             "author": "Manish Singh",
#             "content": "Dream Sports, the parent firm of fantasy sports app Dream11, has secured $400 million in a new financing round as the Mumbai-headquartered firm builds what it calls an end-to-end sports tech company \u2026 [+3063 chars]",
#             "description": "Dream Sports, the parent firm of fantasy sports app Dream11, has secured $400 million in a new financing round as the Mumbai-headquartered firm builds what it calls an \u201cend-to-end sports tech company\u201d in the cricket-loving nation, which is also the world\u2019s se\u2026",
#             "publishedAt": "2021-03-24T10:55:19Z",
#             "source": {
#                 "id": "techcrunch",
#                 "name": "TechCrunch"
#             },
#             "title": "Indian fantasy sports app Dream11\u2019s parent firm raises $400 million",
#             "url": "http://techcrunch.com/2021/03/24/indian-fantasy-sports-app-dream-sports-dream-11-raises-400-million/",
#             "urlToImage": "https://techcrunch.com/wp-content/uploads/2020/09/GettyImages-1148636368.jpg?w=563"
#         },
#         {
#             "author": "Mumbai Mirror",
#             "content": "Mumbai: Carrying forward its ongoing probe into the SUV planting and a Thane businessman's death cases, the National Investigation Agency (NIA\r\n) on Thursday raided a prominent eatery in south Mumbai\u2026 [+1612 chars]",
#             "description": "Carrying forward its ongoing probe into the SUV planting and a Thane businessman's death cases, the National Investigation Agency (NIA) on Thursday raided a prominent eatery in south Mumbai, official",
#             "publishedAt": "2021-04-01T10:13:00Z",
#             "source": {
#                 "id": "the-times-of-india",
#                 "name": "The Times of India"
#             },
#             "title": "Sachin Vaze probe: NIA raids Mumbai eatery in connection to Mukesh Ambani bomb scare - Mumbai Mirror",
#             "url": "https://mumbaimirror.indiatimes.com/mumbai/crime/sachin-vaze-probe-nia-raids-mumbai-eatery-in-connection-to-mukesh-ambani-bomb-scare/articleshow/81833476.cms",
#             "urlToImage": "https://static.toiimg.com/photo/imgsize-361519,msid-81833809/81833809.jpg"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nMUMBAI (Reuters) - At least six people died in a fire that engulfed a mall housing a hospital that treated coronavirus patients in Mumbai, authorities said on Friday.\r\nMore than 70 \u2026 [+765 chars]",
#             "description": "At least six people died in a fire that engulfed a mall housing a hospital that treated coronavirus patients in Mumbai, authorities said on Friday.",
#             "publishedAt": "2021-03-26T05:47:43Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "At least six dead in Mumbai hospital fire - Reuters",
#             "url": "https://www.reuters.com/article/us-health-coronavirus-india-idUSKBN2BI0EO",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210326&t=2&i=1556289434&r=LYNXMPEH2P0A3&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nMUMBAI (Reuters) - At least nine coronavirus patients died in a fire that engulfed a mall housing a hospital in Mumbai, authorities said on Friday.\r\nRescue workers were still workin\u2026 [+1414 chars]",
#             "description": "At least nine coronavirus patients died in a fire that engulfed a mall housing a hospital in Mumbai, authorities said on Friday.",
#             "publishedAt": "2021-03-26T14:51:43Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Nine COVID patients dead in a Mumbai hospital fire - Reuters",
#             "url": "https://www.reuters.com/article/health-coronavirus-india-mumbai-idUSKBN2BI0JB",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210326&t=2&i=1556343236&r=LYNXMPEH2P18I&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nMUMBAI (Reuters) - The Mumbai Indians scout and wicketkeeping consultant Kiran More has tested positive for COVID-19 ahead of the new Indian Premier League (IPL) season, which begin\u2026 [+681 chars]",
#             "description": "The Mumbai Indians scout and wicketkeeping consultant Kiran More has tested positive for COVID-19 ahead of the new Indian Premier League (IPL) season, which begins on Friday.",
#             "publishedAt": "2021-04-06T10:42:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Mumbai Indians staffer tests positive days ahead of IPL start - Reuters",
#             "url": "https://www.reuters.com/article/health-coronavirus-cricket-ipl-idUSKBN2BT187",
#             "urlToImage": "https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800"
#         },
#         {
#             "author": "https://www.facebook.com/bbcnews",
#             "content": "image copyrightGetty Images\r\nimage captionAkshay Kumar is one of the most popular actors in Bollywood\r\nBollywood actor Akshay Kumar has been hospitalised a day after testing positive for Covid-19.\r\nT\u2026 [+1881 chars]",
#             "description": "He is one of several Bollywood stars who have recently tested positive for coronavirus.",
#             "publishedAt": "2021-04-05T05:42:15Z",
#             "source": {
#                 "id": "bbc-news",
#                 "name": "BBC News"
#             },
#             "title": "Akshay Kumar: Bollywood star in hospital with Covid",
#             "url": "https://www.bbc.co.uk/news/world-asia-india-56636782",
#             "urlToImage": "https://ichef.bbci.co.uk/news/1024/branded_news/43B6/production/_117843371_gettyimages-1230390852.jpg"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nCHENNAI, India (Reuters) - The 14th edition of the Indian Premier League (IPL) began with an upset after Virat Kohlis Royal Challengers Bangalore stunned defending champions Mumbai \u2026 [+1528 chars]",
#             "description": "The 14th edition of the Indian Premier League (IPL) began with an upset after Virat Kohli's Royal Challengers Bangalore stunned defending champions Mumbai Indians by two wickets at Chennai's M.A. Chidambaram Stadium on Friday.",
#             "publishedAt": "2021-04-10T02:46:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Bangalore stun champions Mumbai as IPL begins with an upset - Reuters",
#             "url": "https://www.reuters.com/article/cricket-ipl-idUSKBN2BX01Z",
#             "urlToImage": "https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800"
#         },
#         {
#             "author": "Amlan Chakraborty",
#             "content": "NEW DELHI (Reuters) - Mumbai Indians have assembled a side that looks even stronger than their back-to-back title-winning teams, with only Delhi Daredevils and Sunrisers Hyderabad appearing capable o\u2026 [+2411 chars]",
#             "description": "Mumbai Indians have assembled a side that looks even stronger than their back-to-back title-winning teams, with only Delhi Daredevils and Sunrisers Hyderabad appearing capable of denying them a third straight Indian Premier League (IPL) crown.",
#             "publishedAt": "2021-04-08T08:59:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Mumbai go from strength to strength as IPL hat-trick beckons - Reuters",
#             "url": "https://www.reuters.com/article/cricket-ipl-idUSKBN2BV13P",
#             "urlToImage": "https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800"
#         },
#         {
#             "author": "Rajendra Jadhav, Aditya Kalra",
#             "content": "MUMBAI (Reuters) - A senior Mumbai police officer filed a complaint in the Supreme Court on Monday accusing a state government minister of corruption, the latest development in a bizarre case that ha\u2026 [+2240 chars]",
#             "description": "A senior Mumbai police officer filed a complaint in the Supreme Court on Monday accusing a state government minister of corruption, the latest development in a bizarre case that has transfixed the media for weeks.",
#             "publishedAt": "2021-03-22T14:11:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Car bomb, corruption and COVID: 'Sordid' drama rocks India's finance capital - Reuters",
#             "url": "https://www.reuters.com/article/us-india-police-idUSKBN2BE1WT",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210322&t=2&i=1555753879&r=LYNXMPEH2L16X&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nFILE PHOTO: A man and a woman wearing protective face masks walk past a graffiti on a wall, amidst the spread of the coronavirus disease (COVID-19), in Mumbai, India, March 25, 2021\u2026 [+704 chars]",
#             "description": "Maharashtra reported 40,414 new coronavirus cases on Sunday, the highest number reported by any Indian state since March 2020, government data showed.",
#             "publishedAt": "2021-03-28T16:35:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "Maharashtra reports record spike in COVID-19 cases - Reuters",
#             "url": "https://www.reuters.com/article/health-coronavirus-india-cases-idUSKBN2BK0HQ",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210328&t=2&i=1556508703&r=LYNXMPEH2R0DO&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nFILE PHOTO: People wearing protective masks crowd a marketplace amidst the spread of COVID-19 in Mumbai, India, March 22, 2021. REUTERS/Niharika Kulkarni\r\nMUMBAI (Reuters) - The Ind\u2026 [+658 chars]",
#             "description": "The Indian state of Maharashtra reported 40,414 new coronavirus cases on Sunday, the highest number reported by any Indian state since March 2020, government data showed.",
#             "publishedAt": "2021-03-28T16:32:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's Maharashtra state reports record spike in COVID-19 cases - Reuters",
#             "url": "https://www.reuters.com/article/us-health-coronavirus-india-cases-idUSKBN2BK0HO",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210328&t=2&i=1556508670&r=LYNXMPEH2R0DN&w=800"
#         },
#         {
#             "author": "Abhirup Roy",
#             "content": "FILE PHOTO: The ByteDance logo is seen in this illustration taken, Nov. 27, 2019. REUTERS/Dado Ruvic/Illustration/File Photo\r\nMUMBAI (Reuters) - An Indian court on Tuesday dealt a blow to Chinas Byte\u2026 [+674 chars]",
#             "description": "An Indian court on Tuesday dealt a blow to China's ByteDance by dismissing its plea to unblock its bank accounts which have been frozen by federal authorities investigating alleged tax evasion.",
#             "publishedAt": "2021-04-06T10:26:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India court dismisses ByteDance's plea to unblock bank accounts - Reuters UK",
#             "url": "https://www.reuters.com/article/us-bytedance-india-tax-idUSKBN2BT16K",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210406&t=2&i=1557445536&r=LYNXMPEH350KR&w=800"
#         },
#         {
#             "author": "News18",
#             "content": "NCP chief Sharad Pawar has been admitted to Breach Candy Hospital in Mumbai where he is scheduled to undergo a surgery on Monday morning for his gallbladder ailment, party leader Nawab Malik has said\u2026 [+715 chars]",
#             "description": "<ol><li>Sharad Pawar to Undergo Scheduled Surgery Tomorrow, Admitted to Mumbai's Breach Candy\u00a0\u00a0News18\r\n</li><li>Sharad Pawar to undergo gallbladder surgery on Monday: NCP\u00a0\u00a0Mumbai Mirror\r\n</li><li>Sharad Pawar To Undergo Gall Bladder Surgery Tomorrow\u00a0\u00a0NDTV\r\n</\u2026",
#             "publishedAt": "2021-04-11T11:19:00Z",
#             "source": {
#                 "id": null,
#                 "name": "News18"
#             },
#             "title": "Sharad Pawar to Undergo Scheduled Surgery Tomorrow, Admitted to Mumbai's Breach Candy - News18",
#             "url": "https://www.news18.com/news/india/ncp-chief-sharad-pawar-to-undergo-scheduled-surgery-tomorrow-admitted-to-mumbais-breach-candy-hospital-3629639.html",
#             "urlToImage": "https://images.news18.com/ibnlive/uploads/2020/12/1607768434_sharad-pawar-1.jpg"
#         },
#         {
#             "author": "Kelly Beall",
#             "content": "Arjun Rathi\r\nArjun Rathi is an architect and lighting designer with a self-named multi-disciplinary studio, Arjun Rathi Design, that was established in 2012 in Mumbai, India. Since then, his studio\u2019s\u2026 [+3458 chars]",
#             "description": "For this Friday Five, we're spending some time with architect and lighting designer Arjun Rathi and his studio in Mumbai, India!",
#             "publishedAt": "2021-04-02T13:00:43Z",
#             "source": {
#                 "id": null,
#                 "name": "Design-milk.com"
#             },
#             "title": "Friday Five With Arjun Rathi of Arjun Rathi Design",
#             "url": "https://design-milk.com/friday-five-with-arjun-rathi-of-arjun-rathi-design/",
#             "urlToImage": "https://design-milk.com/images/2021/03/F5-Arjun-Rathi-Lodha-World-Towers-Ballroom-Crystal-DNA-2-Photo-Courtesy-Arjun-Rathi-Design.jpg"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nFILE PHOTO: A woman wearing a protective face mask walks past a graffiti, amidst the spread of the coronavirus disease (COVID-19), on a street in Mumbai, India, March 30, 2021. REUT\u2026 [+823 chars]",
#             "description": "India's richest state, Maharashtra, said it would impose stringent COVID-19 restrictions from Monday as there has been a rapid rise in infections, a state minister said on Sunday",
#             "publishedAt": "2021-04-04T12:19:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's richest state says to impose new COVID-19 restrictions, weekend lockdown - Reuters",
#             "url": "https://www.reuters.com/article/us-health-coronavirus-india-maharashtra-idUSKBN2BR0DI",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210404&t=2&i=1557268445&r=LYNXMPEH3306W&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nMUMBAI (Reuters) - Indias daily coronavirus infections hit another record on Saturday for the highest tally since September, while daily deaths reached a five-month high, a Reuters \u2026 [+665 chars]",
#             "description": "India's daily coronavirus infections hit another record on Saturday for the highest tally since September, while daily deaths reached a five-month high, a Reuters count based on data from the health ministry showed.",
#             "publishedAt": "2021-04-03T04:49:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's daily coronavirus infections hit six-month high - Reuters",
#             "url": "https://www.reuters.com/article/us-health-coronavirus-india-cases-idUSKBN2BQ04D",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210403&t=2&i=1557188654&r=LYNXMPEH3202D&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nMUMBAI (Reuters) - India reported 53,480 new cases of the coronavirus, health ministry data showed on Wednesday, the second day that cases have risen less than the day before.\r\nDeat\u2026 [+571 chars]",
#             "description": "India reported 53,480 new cases of the coronavirus, health ministry data showed on Wednesday, the second day that cases have risen less than the day before.",
#             "publishedAt": "2021-03-31T04:32:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India's daily coronavirus cases rise at slower pace than day earlier - Reuters",
#             "url": "https://www.reuters.com/article/health-coronavirus-india-cases-idUSKBN2BN0FG",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210331&t=2&i=1556830655&r=LYNXMPEH2U071&w=800"
#         },
#         {
#             "author": "Reuters Staff",
#             "content": "By Reuters Staff\r\nFILE PHOTO: The logo of the Securities and Exchange Board of India (SEBI), India's market regulator, is seen on the facade of its head office building in Mumbai, India, July 13, 201\u2026 [+780 chars]",
#             "description": "India's market regulator said on Monday that stock exchanges and other market entities will need to switch quicker to their backup sites to resume operations in case of disruptions, weeks after a top exchange was shut down during trading.",
#             "publishedAt": "2021-03-22T14:30:00Z",
#             "source": {
#                 "id": "reuters",
#                 "name": "Reuters"
#             },
#             "title": "India market regulator tightens rules for exchange disruptions - Reuters",
#             "url": "https://www.reuters.com/article/us-india-sebi-exchanges-idUSKBN2BE1YR",
#             "urlToImage": "https://static.reuters.com/resources/r/?m=02&d=20210322&t=2&i=1555755814&r=LYNXMPEH2L186&w=800"
#         }
#     ],
#     "status": "ok",
#     "totalResults": 11087
# }
#             source.id         source.name              author  \
# 0            bbc-news            BBC News                None
# 1                None      New York Times  The New York Times
# 2          techcrunch          TechCrunch        Manish Singh
# 3  the-times-of-india  The Times of India       Mumbai Mirror
# 4             reuters             Reuters       Reuters Staff
#
#                                                title  \
# 0  Defending champions Mumbai stifle Kolkata for ...
# 1  Covid Updates: Spring Breakers Defy Curfew in ...
# 2  Indian fantasy sports app Dream11’s parent fir...
# 3  Sachin Vaze probe: NIA raids Mumbai eatery in ...
# 4  At least six dead in Mumbai hospital fire - Re...
#
#                                          description  \
# 0  Defending champions Mumbai Indians somehow ear...
# 1  New York finds its first case of a troubling v...
# 2  Dream Sports, the parent firm of fantasy sport...
# 3  Carrying forward its ongoing probe into the SU...
# 4  At least six people died in a fire that engulf...
#
#                                                  url  \
# 0       https://www.bbc.co.uk/sport/cricket/56712922
# 1  https://www.nytimes.com/live/2021/03/21/world/...
# 2  http://techcrunch.com/2021/03/24/indian-fantas...
# 3  https://mumbaimirror.indiatimes.com/mumbai/cri...
# 4  https://www.reuters.com/article/us-health-coro...
#
#                                           urlToImage           publishedAt  \
# 0  https://ichef.bbci.co.uk/live-experience/cps/6...  2021-04-13T18:20:45Z
# 1  https://static01.nyt.com/images/2021/03/21/wor...  2021-03-21T14:57:26Z
# 2  https://techcrunch.com/wp-content/uploads/2020...  2021-03-24T10:55:19Z
# 3  https://static.toiimg.com/photo/imgsize-361519...  2021-04-01T10:13:00Z
# 4  https://static.reuters.com/resources/r/?m=02&d...  2021-03-26T05:47:43Z
#
#                                              content
# 0  Mumbai Indians lost their opening game of the ...
# 1  LiveUpdated March 21, 2021, 11:04 a.m. ET\r\nM...
# 2  Dream Sports, the parent firm of fantasy sport...
# 3  Mumbai: Carrying forward its ongoing probe int...
# 4  By Reuters Staff\r\nMUMBAI (Reuters) - At leas...
# Enter Location: india
#                                                 title  \
# 0                Brahmaputra River, India | Earthdata
# 1                Fires in Northwest India | Earthdata
# 2   High Aerosol Index Over Northern India | Earth...
# 3       Fires and Smoke in Northern India | Earthdata
# 4   Tropical Cyclone Vardah approaching India | Ea...
# 5   Smoke and fires in northwest India—November 20...
# 6   Smoke and Fires in Northwest India—November 20...
# 7   High Aerosol Optical Depth over Northern India...
# 8                 From Indonesia to India | Earthdata
# 9             Spatial Data from the 2011 India Census
# 10        India Annual Winter Cropped Area, 2001-2016
# 11      NPP Grassland: Vindhyan, India, 1986-1989, R1
# 12  India Village-Level Geospatial Socio-Economic ...
# 13   NPP Grassland: Kurukshetra, India, 1970-1971, R1
# 14  Decadal Land Use and Land Cover Classification...
# 15           User Profile: Dr. Karen Seto | Earthdata
# 16  LP DAAC - MODIS Captures Indirect Impacts of C...
# 17         User Profile: Dr. Pinki Mondal | Earthdata
# 18                 Paving a new lifestyle | Earthdata
# 19    Worldview Image of the Week Archive | Earthdata
# 20    Worldview Image of the Week Archive | Earthdata
# 21  Can Citizen Science and Low-Cost Sensors Help ...
# 22                       The price of tea | Earthdata
# 23  Effects of Emissions on Climate Change | Earth...
# 24        User Profile: Dr. Steven Massie | Earthdata
# 25          User Profile: Dr. Brian Mapes | Earthdata
# 26       User Profile: Dr. Faisal Hossain | Earthdata
# 27           EOSDIS Data News: April 2018 | Earthdata
# 28           EOSDIS Data News: March 2018 | Earthdata
# 29              Squeezing Water from Rock | Earthdata
# 30           When the Earth moved Kashmir | Earthdata
# 31              And the Winners Are . . . | Earthdata
# 32  LP DAAC - Highlights from the Literature: Octo...
# 33  LP DAAC - Irrigation and Land Use Change in Ta...
# 34  Country-Level Population and Downscaled Projec...
# 35                                  LP DAAC - MYD21A2
# 36               A kink in the jet stream | Earthdata
# 37  Tropical Cyclone Amphan in the Bay of Bengal |...
# 38               Karakoram Mountain Range | Earthdata
# 39                         The Sundarbans | Earthdata
#
#                                           description  \
# 0   ...visualizations of the Brahmaputra River in ...
# 1   ...visualizations of fires in northwest India ...
# 2   ...of high aerosol index over Northern India, ...
# 3   ...visualizations of fires and smoke in North ...
# 4   ...visualizations of Tropical Cyclone Vardah n...
# 5   ...visualizations of smoke and fires in Northw...
# 6   ...ns of smoke and fires in Northwest India fr...
# 7   ...of high aerosol optical depth over India fr...
# 8   Sensing Our Planet From Indonesia to India Dat...
# 9   ...from the 2011 India Census The Spatial Data...
# 10  CIESIN_SEDAC_INDIA_AWCA India Annual Winter Cr...
# 11  NPP_VND_197 NPP Grassland: Vindhyan, India, 19...
# 12  Name: CIESIN_SEDAC_INDIA_VILSOCIOECON India Vi...
# 13  NPP_KRK_193 NPP Grassland: Kurukshetra, India,...
# 14  ...and Land Cover Classifications across India...
# 15  ...with a particular research emphasis on Indi...
# 16  ...impacted economic growth globally. India ha...
# 17  ...2000-2016 wet season/monsoon in South Asia/...
# 18  ...20th century, familiar illnesses in India i...
# 19  Aerosol Index, India 11/09/2020 High Aerosol I...
# 20  Aerosol Index, India 11/09/2020 High Aerosol I...
# 21  Raleigh, North Carolina; and Delhi, India. The...
# 22  ...quality and crop yield have declined. In In...
# 23  France, Russia, Poland, Japan, China, India, B...
# 24  ...like Beijing, China, and New Delhi, India, ...
# 25  ...at the Ellora Caves in Maharashtra, India, ...
# 26  ...northwestward through Tibet and into India,...
# 27  ...completed a production release of the India...
# 28  SEDAC completed a beta release of the India Vi...
# 29  Structures in the village of Bhuj, India, whic...
# 30  ...neighboring countries of Pakistan and India...
# 31  Overflow (Vallabh Vidhya Nagar, Anand, India) ...
# 32  Vegetation Index data over Odisha, India, shor...
# 33  ...2015 A farm in Kukkal, Tamil Nadu, India ca...
# 34  ...including Africa, Asia (minus India and Chi...
# 35  ...from the MYD21A2 product over India on Indi...
# 36  ...that pours on the Bay of Bengal in India. “...
# 37  ...is projected to make landfall at the India-...
# 38  ...range spanning the borders of Pakistan, Ind...
# 39  ...mangrove forest part of which is in India a...
#
#                                                  link
# 0   https://earthdata.nasa.gov/worldview/worldview...
# 1   https://earthdata.nasa.gov/worldview/worldview...
# 2   https://earthdata.nasa.gov/worldview/worldview...
# 3   https://earthdata.nasa.gov/worldview/worldview...
# 4   https://earthdata.nasa.gov/worldview/worldview...
# 5   https://earthdata.nasa.gov/worldview/worldview...
# 6   https://earthdata.nasa.gov/worldview/worldview...
# 7   https://earthdata.nasa.gov/worldview/worldview...
# 8   https://earthdata.nasa.gov/learn/sensing-our-p...
# 9   https://cmr.earthdata.nasa.gov/search/concepts...
# 10  https://cmr.earthdata.nasa.gov/search/concepts...
# 11  https://cmr.earthdata.nasa.gov/search/concepts...
# 12  https://cmr.earthdata.nasa.gov/search/concepts...
# 13  https://cmr.earthdata.nasa.gov/search/concepts...
# 14  https://cmr.earthdata.nasa.gov/search/concepts...
# 15  https://earthdata.nasa.gov/learn/user-resource...
# 16  https://lpdaac.usgs.gov/resources/data-action/...
# 17  https://earthdata.nasa.gov/learn/user-resource...
# 18  https://earthdata.nasa.gov/learn/sensing-our-p...
# 19  https://earthdata.nasa.gov/worldview/worldview...
# 20  https://earthdata.nasa.gov/worldview/worldview...
# 21  https://earthdata.nasa.gov/esds/competitive-pr...
# 22  https://earthdata.nasa.gov/learn/sensing-our-p...
# 23  https://earthdata.nasa.gov/learn/sensing-our-p...
# 24  https://earthdata.nasa.gov/learn/user-resource...
# 25  https://earthdata.nasa.gov/learn/user-resource...
# 26  https://earthdata.nasa.gov/learn/user-resource...
# 27  https://earthdata.nasa.gov/eosdis-data-news-ar...
# 28  https://earthdata.nasa.gov/eosdis-data-news-ar...
# 29  https://earthdata.nasa.gov/learn/sensing-our-p...
# 30  https://earthdata.nasa.gov/learn/sensing-our-p...
# 31  https://earthdata.nasa.gov/learn/articles/2020...
# 32  https://lpdaac.usgs.gov/resources/data-action/...
# 33  https://lpdaac.usgs.gov/resources/data-action/...
# 34  https://cmr.earthdata.nasa.gov/search/concepts...
# 35      https://lpdaac.usgs.gov/products/myd21a2v061/
# 36  https://earthdata.nasa.gov/learn/sensing-our-p...
# 37  https://earthdata.nasa.gov/worldview/worldview...
# 38  https://earthdata.nasa.gov/worldview/worldview...
# 39  https://earthdata.nasa.gov/worldview/worldview...
# Web Scraping Successful!
